# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

# Original feature (single feature)
X = np.array([[2], [3], [5]])  # Example data: house sizes

# Create polynomial features (up to degree 3)
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

# Display the original and polynomial features
print("Original feature (X):")
print(X)
print("\nPolynomial features (X_poly):")
print(X_poly)
# Out:
# Original feature (X):
# [[2]
#  [3]
#  [5]]
#
# Polynomial features (X_poly):
# [[  1.   2.   4.   8.]
#  [  1.   3.   9.  27.]
#  [  1.   5.  25. 125.]]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Original feature (single feature)
X = np.array([[2], [3], [5]])  # Example data: house sizes
y = np.array([6, 9, 15])  # Example target: house prices

# Create polynomial features (up to degree 3)
poly = PolynomialFeatures(degree=3)
X_poly = poly.fit_transform(X)

# Linear regression on original feature
model_linear = LinearRegression()
model_linear.fit(X, y)
y_linear_pred = model_linear.predict(X)

# Linear regression on polynomial feature (x^2)
model_poly = LinearRegression()
model_poly.fit(X_poly[:, 1:2], y)  # Use only x^2 feature
y_poly_pred = model_poly.predict(X_poly[:, 1:2])

# Plotting
plt.figure(figsize=(12, 5))

# Scatter plot of original data
plt.subplot(1, 2, 1)
plt.scatter(X, y, color='blue', label='Data')
plt.plot(X, y_linear_pred, color='red', label='Linear Fit')
plt.xlabel('House Size')
plt.ylabel('House Price')
plt.title('Linear Regression (Single Feature)')
plt.legend()

# Scatter plot of polynomial feature (x^2)
plt.subplot(1, 2, 2)
plt.scatter(X_poly[:, 1], y, color='blue', label='Data')
plt.plot(X_poly[:, 1], y_poly_pred, color='green', label='Linear Fit (x^2)')
plt.xlabel('House Size (Squared)')
plt.ylabel('House Price')
plt.title('Linear Regression (Polynomial Feature: x^2)')
plt.legend()

plt.tight_layout()
plt.show()

# %%
import numpy as np
import pandas as pd

series = pd.Series([1,2,3, np.nan, 6, 7])
series
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    6.0
# 5    7.0
# dtype: float64

# %%
dates = pd.date_range("20240401", periods=5)


day_name = dates.day_name()

df = pd.DataFrame({"Date": dates, "Day": day_name})
df
# Out:
#         Date        Day
# 0 2024-04-01     Monday
# 1 2024-04-02    Tuesday
# 2 2024-04-03  Wednesday
# 3 2024-04-04   Thursday
# 4 2024-04-05     Friday

# %%
df = pd.DataFrame(np.random.rand(2,3) , index=dates)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 df = pd.DataFrame(np.random.rand(2,3) , index=dates)
#       2 df
#
# File ~/Projects/AI-Muhsin-Ahmad-OPA23/venv/lib/python3.9/site-packages/pandas/core/frame.py:816, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     805         mgr = dict_to_mgr(
#     806             # error: Item "ndarray" of "Union[ndarray, Series, Index]" has no
#     807             # attribute "name"
#    (...)
#     813             copy=_copy,
#     814         )
#     815     else:
# --> 816         mgr = ndarray_to_mgr(
#     817             data,
#     818             index,
#     819             columns,
#     820             dtype=dtype,
#     821             copy=copy,
#     822             typ=manager,
#     823         )
#     825 # For data is list-like, or Iterable (will consume into list)
# ...

# %%
import seaborn as sns

df = sns.load_dataset('titanic')
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
df =df.drop(columns=['deck'])
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male  embark_town alive  alone
# ...

# %%
df.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %%
df.isnull().sum()
# Out:
# survived         0
# pclass           0
# sex              0
# age            177
# sibsp            0
# parch            0
# fare             0
# embarked         2
# class            0
# who              0
# adult_male       0
# embark_town      2
# alive            0
# alone            0
# dtype: int64

# %%
df.isnull().sum()*100/len(df)
# Out:
# survived        0.000000
# pclass          0.000000
# sex             0.000000
# age            19.865320
# sibsp           0.000000
# parch           0.000000
# fare            0.000000
# embarked        0.224467
# class           0.000000
# who             0.000000
# adult_male      0.000000
# embark_town     0.224467
# alive           0.000000
# alone           0.000000
# dtype: float64

# %%
sns.countplot(data=df , x= "survived")
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.barplot(data= df , x= "survived" , y= "age" , hue= "who")
# Out:
# <Axes: xlabel='survived', ylabel='age'>

# %%
sns.histplot(data=df , x="age" , bins=20)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxenplot(data=df, y="fare" , x= "survived" , hue="who")
# Out:
# <Axes: xlabel='survived', ylabel='fare'>

# %%
sns.scatterplot(data= df , x="age", y="fare")
plt.ylim(0,175)
# Out:
# (0.0, 175.0)

# %%
sns.pairplot(df , hue="survived")

# %%
df["age_group"] = pd.cut(df["age"] , [0,10,20,30,40,50,60,70,80], labels= ["Kid" , "Child", "young", "mid_young" , "Adult" , "Man", "old", "super_old"])
df
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
# ...

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# Sample data (exam scores and grades)
exam_scores = np.array([75, 80, 65, 90, 85, 70, 95, 60, 55, 50])
grades = np.array(['B', 'A', 'C', 'A', 'A', 'B', 'A', 'D', 'D', 'F'])

# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(
    exam_scores, grades, test_size=0.2, random_state=42)

# Check the shapes of the resulting training and testing sets
print(f"Training set size: {len(X_train)}")
print(f"Testing set size: {len(X_test)}")
print(f"Training set size: {len(y_train)}")
print(f"Testing set size: {len(y_test)}")
# Out:
# Training set size: 8
# Testing set size: 2
# Training set size: 8
# Testing set size: 2

# %%
import numpy as np

# Sample data
age = np.array([20, 30, 40, 50, 60, 70, 80])
income = np.array([20, 40, 60, 80, 100, 120, 200])

# Min-Max Scaling
age_scaled = (age - age.min()) / (age.max() - age.min())
income_scaled = (income - income.min()) / (income.max() - income.min())

# Standardization
age_mean = age.mean()
age_std = age.std()
income_mean = income.mean()
income_std = income.std()

age_standardized = (age - age_mean) / age_std
income_standardized = (income - income_mean) / income_std

print("Age (original):", age)
print("Income (original):", income)
print("Age (scaled):", age_scaled)
print("Income (scaled):", income_scaled)
print("Age (standardized):", age_standardized)
print("Income (standardized):", income_standardized)
# Out:
# Age (original): [20 30 40 50 60 70 80]
# Income (original): [ 20  40  60  80 100 120 200]
# Age (scaled): [0.         0.16666667 0.33333333 0.5        0.66666667 0.83333333
#  1.        ]
# Income (scaled): [0.         0.11111111 0.22222222 0.33333333 0.44444444 0.55555556
#  1.        ]
# Age (standardized): [-1.5 -1.  -0.5  0.   0.5  1.   1.5]
# Income (standardized): [-1.2377055  -0.87670806 -0.51571062 -0.15471319  0.20628425  0.56728169
#   2.01127143]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Number of car samples
samples = 10

# Generate ages of cars (in years) between 0 and 10
age = np.random.uniform(0, 10, (samples, 1))

# Define a function to calculate car prices based on age
def calculate_price(age):
    return age**2 + 0.5*age + 3  # Price = age^2 + 0.5*age + 3

# Calculate prices for each age with some random noise
price = calculate_price(age) + np.random.randn(samples, 1)

# Generate ages for plotting
x = np.linspace(0, 10, samples)

# Plot the car ages and prices
plt.plot(age, price, '.', label='Car Data')
plt.plot(x, calculate_price(x), label='Original Price Function')
plt.xlabel('Age (Years)')
plt.ylabel('Price ($)')
plt.legend()
plt.title('Car Price Prediction')
plt.show()

# %%
import pandas as pd

# Sample dataset
data = {'Date': ['2022-01-01', '2022-01-02', '2022-01-03'],
        'Sales': [100, 150, 200]}
df = pd.DataFrame(data)

# Feature engineering: Extracting features from Date
df['Date'] = pd.to_datetime(df['Date'])
df['Day_of_Week'] = df['Date'].dt.dayofweek
df['Month'] = df['Date'].dt.month
df['Year'] = df['Date'].dt.year

print(df)
# Out:
#         Date  Sales  Day_of_Week  Month  Year
# 0 2022-01-01    100            5      1  2022
# 1 2022-01-02    150            6      1  2022
# 2 2022-01-03    200            0      1  2022

# %%
from sklearn.preprocessing import PolynomialFeatures

# Sample dataset
X = [[1], [2], [3]]

# Polynomial feature engineering
poly = PolynomialFeatures(degree=2)
X_poly = poly.fit_transform(X)

print(X_poly)
# Out:
# [[1. 1. 1.]
#  [1. 2. 4.]
#  [1. 3. 9.]]

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating random data points
X = np.random.uniform(-3, 3, 100)  # Generate 100 random numbers between -3 and 3

# Defining a quadratic function: f(x) = x^2 + 0.5x + 3
def f(x):
    return x**2 + 0.5*x + 3

# Generating corresponding y values
y = f(X) + np.random.randn(100)  # Add some random noise to the function values

# Plotting the data points and the quadratic function
plt.plot(X, y, 'b.')  # Plot the data points in blue dots
plt.xlabel('X')  # Label for x-axis
plt.ylabel('y')  # Label for y-axis

# Generating a range of x values to plot the quadratic function
x_values = np.linspace(-3, 3, 100)  # Generate 100 equally spaced points between -3 and 3

# Plotting the quadratic function
plt.plot(x_values, f(x_values), 'r-')  # Plot the quadratic function in red

plt.show()  # Display the plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating 100 random points between -3 and 3
X = np.random.uniform(-3, 3, 100)

# Plotting the data points
plt.plot(X, 'b.')  # Plot the points as blue dots
plt.xlabel('Index')  # Label for x-axis
plt.ylabel('Value')  # Label for y-axis
plt.title('Random Data Points')  # Title for the plot
plt.show()  # Display the plot

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generating equally spaced x values between -3 and 3
x_values = np.linspace(-3, 3, 100)

# Defining the quadratic function: f(x) = x^2 + 0.5x + 3
f = lambda x: x**2 + 0.5*x + 3

# Plotting the line
plt.plot(x_values, f(x_values), color='red', label='Quadratic Curve')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

samples = 100
X = np.random.uniform(-3, 3, samples)

# Defining the quadratic function: f(x) = x^2 + 0.5x + 3
f = lambda x: x**2 + 0.5*x + 3

# Generating the corresponding y values
y = f(X) + np.random.randn(samples)

# Plotting the scattered points
plt.scatter(X, y, color='blue', label='Scattered Points')
plt.xlabel('X')
plt.ylabel('Y')
plt.legend()
plt.show()

# %%
import seaborn as sns
sample = 50
x_vales = np.random.uniform(-3,3, sample)

f = lambda x: x**2 + 0.5*x + 3

y = f(x_vales) + np.random.randn(sample)

plt.scatter(x_vales, y)

# %%
sample = 100
x_vale = np.linspace(-3,3 , sample)

f = lambda x : x**2 + 0.5*x + 3

plt.plot(x_vale , f(x_vale))

# %%
sample = 100

X = np.random.uniform(-3, 3 , (sample,1))

f = lambda x: x**2 + 0.5*x + 3

y = f(X) + np.random.randn(sample, 1)

x = np.linspace(-3,3 , sample)

plt.plot(X , y, '.')
plt.plot(x , f(x))

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate synthetic data with a nonlinear relationship
X = np.linspace(-3, 3, 50)
y = X**2 + np.random.normal(0, 1, 50)  # Quadratic relationship with some noise

# Reshape X to a column vector
X = X.reshape(-1, 1)

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Plot the data points
plt.scatter(X, y, color='blue', label='Data')

# Plot the predicted values from the linear regression model
plt.plot(X, model.predict(X), color='red', label='Linear Regression')

plt.xlabel('X')
plt.ylabel('y')
plt.title('Underfitting Example')
plt.legend()
plt.show()

# %%
x = np.linspace(-3,3,50)
y = x**2 + np.random.normal(0,1,50)

x= x.reshape(-1,1)
model = LinearRegression()
model.fit(x,y)

plt.plot(x , model.predict(x))

plt.scatter(x,y)

# %%
model = LinearRegression()
model.fit(x,y)

plt.plot(x , model.predict(x))

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

# Generate polynomial features
poly_features = PolynomialFeatures(degree=2)  # Use degree=2 for quadratic relationship
X_poly = poly_features.fit_transform(x)

# Fit polynomial regression model
poly_model = LinearRegression()
poly_model.fit(X_poly, y)

# Predict y values using the polynomial model
y_pred = poly_model.predict(X_poly)

# Plot the polynomial curve and scatter points
plt.scatter(x, y, label='Original Data')
plt.plot(x, y_pred, color='red', label='Polynomial Fit')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Polynomial Regression')
plt.legend()
plt.show()

# %%
import numpy as np
from sklearn.preprocessing import PolynomialFeatures

# Suppose we have a single feature (X) with 5 data points
X = np.array([1, 2, 3, 4, 5]).reshape(-1, 1)

# Create a PolynomialFeatures object with degree=3 (up to cubic)
poly_model_3 = PolynomialFeatures(degree=3, include_bias=False)

# Apply polynomial feature expansion to the original feature
X_features = poly_model_3.fit_transform(X)

# Print the shape of the transformed feature matrix
print("Shape of transformed feature matrix:", X_features.shape)
# Out:
# Shape of transformed feature matrix: (5, 3)

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error

np.random.seed(0)
x = np.linspace(-3,3 , 100)
y = x**2 + np.random.randn(0,1,100)

x =x.reshape(-1,1)

x_train , x_test = x[:70], x[70:]
y_train , y_test = y[:70] , y[70:]

ploy = PolynomialFeatures(degree= 30)
x_train_poly = ploy.fit_transform(x_train)
x_test_poly = ploy.transform(x_test)

model = LinearRegression()
model.fit(x_train_poly , y_train)

y_train_pred = model.predict(x_train_poly)
y_test_pred = model.predict(x_test_poly)



plt.scatter(x , y, color= "red")
plt.plot(x,  model.predict(ploy.transform(x)) , color = "blue")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 21
#      18 x_test_poly = ploy.transform(x_test)
#      20 model = LinearRegression()
# ---> 21 model.fit(x_train_poly , y_train)
#      23 y_train_pred = model.predict(x_train_poly)
#      24 y_test_pred = model.predict(x_test_poly)
#
# File ~/Projects/AI-Muhsin-Ahmad-OPA23/venv/lib/python3.9/site-packages/sklearn/base.py:1474, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1467     estimator._validate_params()
#    1469 with config_context(
#    1470     skip_parameter_validation=(
#    1471         prefer_skip_nested_validation or global_skip_validation
#    1472     )
#    1473 ):
# -> 1474     return fit_method(estimator, *args, **kwargs)
#
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.preprocessing import PolynomialFeatures
from sklearn.linear_model import LinearRegression

np.random.seed(0)
x = np.linspace(-3, 3, 100)
y = x**2 + np.random.normal(0, 1, 100)

x = x.reshape(-1, 1)

x_train, x_test = x[:70], x[70:]
y_train, y_test = y[:70], y[70:]

poly = PolynomialFeatures(degree=30)
x_train_poly = poly.fit_transform(x_train)
x_test_poly = poly.transform(x_test)

model = LinearRegression()
model.fit(x_train_poly, y_train)

y_train_pred = model.predict(x_train_poly)
y_test_pred = model.predict(x_test_poly)

plt.scatter(x, y, color='blue')  # Fix color to match scatter points with the line
plt.plot(x, model.predict(poly.transform(x)), color='red')
plt.xlabel('X')
plt.ylabel('y')
plt.title('Polynomial Regression (Degree=30)')
plt.show()

# %%
import pandas as pd

data = {
    'date' : ['2021-12-01', '01-12-2022', '2022/12/01','12-01-2021'],
    'country': ['USA', 'U.S.A', 'America', 'United Stated'],
    'name': ['John Doe', 'Jonh Doe', 'Jane Doe', 'Jane Doe'],
    'sales_2020': [100,200, None, 200],
    'sales_-2021': [None,150, 300,150]
}

df = pd.DataFrame(data)
df
# Out:
#          date        country      name  sales_2020  sales_-2021
# 0  2021-12-01            USA  John Doe       100.0          NaN
# 1  01-12-2022          U.S.A  Jonh Doe       200.0        150.0
# 2  2022/12/01        America  Jane Doe         NaN        300.0
# 3  12-01-2021  United Stated  Jane Doe       200.0        150.0

# %%
# standardizing the date formate

#df['date'] = pd.to_datetime(df['date'] , errors='coerce')

# %%
country_name = {'USA': 'United State', 'U.S.A': 'United Stated', 'America': 'United Stated'}

df['country'] = df['country'].replace(country_name)
df
# Out:
#          date        country      name  sales_2020  sales_-2021
# 0  2021-12-01   United State  John Doe       100.0          NaN
# 1  01-12-2022  United Stated  Jonh Doe       200.0        150.0
# 2  2022/12/01  United Stated  Jane Doe         NaN        300.0
# 3  12-01-2021  United Stated  Jane Doe       200.0        150.0

# %%
# removie duplicates

df = df.drop_duplicates()

# %%
df = pd.read_csv("../data/Advertising.csv", index_col=0)
df.head()
# Out:
#       TV  Radio  Newspaper  Sales
# 1  230.1   37.8       69.2   22.1
# 2   44.5   39.3       45.1   10.4
# 3   17.2   45.9       69.3    9.3
# 4  151.5   41.3       58.5   18.5
# 5  180.8   10.8       58.4   12.9

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 200 entries, 1 to 200
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 7.8 KB

# %%
X , y = df.drop("Sales" , axis= "columns"), df["Sales"]
X
# Out:
#         TV  Radio  Newspaper
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# ..     ...    ...        ...
# 196   38.2    3.7       13.8
# 197   94.2    4.9        8.1
# 198  177.0    9.3        6.4
# 199  283.6   42.0       66.2
# 200  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y
# Out:
# 1      22.1
# 2      10.4
# 3       9.3
# 4      18.5
# 5      12.9
#        ...
# 196     7.6
# 197     9.7
# 198    12.8
# 199    25.5
# 200    13.4
# Name: Sales, Length: 200, dtype: float64

# %%
from sklearn.model_selection import train_test_split

# help(train_test_split)

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

X_train.shape , X_test.shape , y_train.shape , y_test.shape
# Out:
# ((140, 3), (60, 3), (140,), (60,))

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

scaler.fit(X_train)
scaler
# Out:
# MinMaxScaler()

# %%
scaled_X_train = scaler.transform(X_train)

scaled_X_test = scaler.transform(X_test)


scaled_X_train.shape , scaled_X_train.min() , scaled_X_train.max()
# Out:
# ((140, 3), 0.0, 1.0)

# %%
scaled_X_test.min(), scaled_X_test.max() , scaled_X_test.shape
# Out:
# (0.005964214711729622, 1.1302186878727631, (60, 3))

# %%
import numpy as np
import matplotlib.pyplot as plt

sample = 100

X = np.random.uniform(-3,3 , (sample, 1))
X.shape
# Out:
# (100, 1)

# %%
f = lambda x:  x**2 + 0.5*x + 3

y = f(X) + np.random.randn(sample, 1)

x = np.linspace(-3,3, sample)

plt.plot(X,y, '.')
plt.plot(x , f(x))

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2 , include_bias=False)

poly_features = poly.fit_transform(X)
poly_features.shape , poly_features[:5]
# Out:
# ((100, 2),
#  array([[ 2.64826623,  7.01331402],
#         [ 1.79521552,  3.22279878],
#         [ 0.78268762,  0.61259991],
#         [ 2.2457278 ,  5.04329335],
#         [-1.24187829,  1.54226169]]))

# %%
from sklearn.linear_model import LinearRegression

mode = LinearRegression()
model.fit(poly_features , y)

model.coef_
# Out:
# array([[0.45188529, 1.04351283]])

# %% [markdown]
# # underfitting

# %%
def draw_data():
    fig, ax = plt.subplots()
    ax.plot(X,y, '.', label="data")
    ax.plot(x, f(x), label="true function")
    ax.set(title = r"$y = x^2+0.5x+3+\epsilon$")
    ax.legend()

    return ax
draw_data()
# Out:
# <Axes: title={'center': '$y = x^2+0.5x+3+\\epsilon$'}>

# %%
model = LinearRegression()

model.fit(X, y)
ax = draw_data()
ax.plot(x, model.predict(x.reshape(-1,1)))

# %%
poly_model = PolynomialFeatures(30 , include_bias=False)

X_features = poly_model.fit_transform(X)
X_features.shape
# Out:
# (100, 30)

# %%
x_poly_features = poly_model.transform(x.reshape(-1,1))
x_poly_features.shape
# Out:
# (100, 30)

# %%
model = LinearRegression()

model.fit(X_features , y)

y_pred = model.predict(x_poly_features)

ax = draw_data()
ax.plot(x,y_pred)
ax.set(ylim=[-1,15] , title="overfitting")
# Out:
# [(-1.0, 15.0), Text(0.5, 1.0, 'overfitting')]

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# Generate some synthetic data
np.random.seed(0)
X = np.random.rand(20, 1) * 10  # House sizes
y = 3 * X + np.random.randn(20, 1) * 10  # Prices with some noise

# Fit a linear regression model
model = LinearRegression()
model.fit(X, y)

# Plot the data and the linear regression line
plt.scatter(X, y, label='Data')
plt.plot(X, model.predict(X), color='red', label='Linear Regression')
plt.xlabel('House Size')
plt.ylabel('Price')
plt.title('Underfitting Example')
plt.legend()
plt.show()

# %%
from sklearn.preprocessing import PolynomialFeatures

# Generate some synthetic data
np.random.seed(0)
X = np.random.rand(20, 1) * 10  # House sizes
y = 3 * X + np.random.randn(20, 1) * 10  # Prices with some noise

# Generate polynomial features up to degree 15
poly_features = PolynomialFeatures(degree=15, include_bias=False)
X_poly = poly_features.fit_transform(X)

# Fit a linear regression model
model = LinearRegression()
model.fit(X_poly, y)

# Plot the data and the polynomial regression curve
plt.scatter(X, y, label='Data')
plt.plot(X, model.predict(X_poly), color='red', label='Polynomial Regression (degree=15)')
plt.xlabel('House Size')
plt.ylabel('Price')
plt.title('Overfitting Example')
plt.legend()
plt.show()

# %%
import seaborn as sns

df = pd.read_csv("../data/Advertising.csv" , index_col=0)
df
# Out:
#         TV  Radio  Newspaper  Sales
# 1    230.1   37.8       69.2   22.1
# 2     44.5   39.3       45.1   10.4
# 3     17.2   45.9       69.3    9.3
# 4    151.5   41.3       58.5   18.5
# 5    180.8   10.8       58.4   12.9
# ..     ...    ...        ...    ...
# 196   38.2    3.7       13.8    7.6
# 197   94.2    4.9        8.1    9.7
# 198  177.0    9.3        6.4   12.8
# 199  283.6   42.0       66.2   25.5
# 200  232.1    8.6        8.7   13.4
#
# [200 rows x 4 columns]

# %%
from sklearn.preprocessing import PolynomialFeatures
from sklearn.model_selection import train_test_split

X , y = df.drop("Sales" , axis= 1) , df["Sales"]
X
# Out:
#         TV  Radio  Newspaper
# 1    230.1   37.8       69.2
# 2     44.5   39.3       45.1
# 3     17.2   45.9       69.3
# 4    151.5   41.3       58.5
# 5    180.8   10.8       58.4
# ..     ...    ...        ...
# 196   38.2    3.7       13.8
# 197   94.2    4.9        8.1
# 198  177.0    9.3        6.4
# 199  283.6   42.0       66.2
# 200  232.1    8.6        8.7
#
# [200 rows x 3 columns]

# %%
y[:5]
# Out:
# 1    22.1
# 2    10.4
# 3     9.3
# 4    18.5
# 5    12.9
# Name: Sales, dtype: float64

# %%
model_polynomial = PolynomialFeatures(3 , include_bias=False)
poly_features = model_polynomial.fit_transform(X)
poly_features.shape
# Out:
# (200, 19)

# %%
X_train , X_test , y_train , y_test = train_test_split(poly_features , y , test_size=0.33 , random_state=42)

X_train.shape , X_test.shape , y_train.shape , y_test.shape
# Out:
# ((134, 19), (66, 19), (134,), (66,))

# %%
df = pd.read_csv("../data/Default.csv")
df
# Out:
#      default student      balance        income
# 0         No      No   729.526495  44361.625074
# 1         No     Yes   817.180407  12106.134700
# 2         No      No  1073.549164  31767.138947
# 3         No      No   529.250605  35704.493935
# 4         No      No   785.655883  38463.495879
# ...      ...     ...          ...           ...
# 9995      No      No   711.555020  52992.378914
# 9996      No      No   757.962918  19660.721768
# 9997      No      No   845.411989  58636.156984
# 9998      No      No  1569.009053  36669.112365
# 9999      No     Yes   200.922183  16862.952321
#
# [10000 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   default  10000 non-null  object
#  1   student  10000 non-null  object
#  2   balance  10000 non-null  float64
#  3   income   10000 non-null  float64
# dtypes: float64(2), object(2)
# memory usage: 312.6+ KB

# %%
df["default"].value_counts()
# Out:
# default
# No     9667
# Yes     333
# Name: count, dtype: int64

# %%
df["student"].value_counts()
# Out:
# student
# No     7056
# Yes    2944
# Name: count, dtype: int64

# %%
sns.scatterplot(data=df , x= "balance" , y = "income" , hue="default")
# Out:
# <Axes: xlabel='balance', ylabel='income'>

# %%
pd.get_dummies(df , columns= ["default" , "student"]).head()
# Out:
#        balance        income  default_No  default_Yes  student_No  student_Yes
# 0   729.526495  44361.625074        True        False        True        False
# 1   817.180407  12106.134700        True        False       False         True
# 2  1073.549164  31767.138947        True        False        True        False
# 3   529.250605  35704.493935        True        False        True        False
# 4   785.655883  38463.495879        True        False        True        False

# %%
df = pd.get_dummies(df, columns=["default" , "student"] , drop_first=True)
df.head()
# Out:
#        balance        income  default_Yes  student_Yes
# 0   729.526495  44361.625074        False        False
# 1   817.180407  12106.134700        False         True
# 2  1073.549164  31767.138947        False        False
# 3   529.250605  35704.493935        False        False
# 4   785.655883  38463.495879        False        False
